# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv('https://raw.githubusercontent.com/leoferres/gitiele356b/main/data/bwt.csv')

# %%
data
# Out:
#       bwt  gestation  parity  age  height  weight  smoke
# 0     120        284       0   27      62     100      0
# 1     113        282       0   33      64     135      0
# 2     128        279       0   28      64     115      1
# 3     108        282       0   23      67     125      1
# 4     136        286       0   25      62      93      0
# ...   ...        ...     ...  ...     ...     ...    ...
# 1169  113        275       1   27      60     100      0
# 1170  128        265       0   24      67     120      0
# 1171  130        291       0   30      65     150      1
# 1172  125        281       1   21      65     110      0
# 1173  117        297       0   38      65     129      0
#
# [1174 rows x 7 columns]

# %%
data['altura_madre_cms'] = data['height']*2.54

# %%
data['peso_guagua_kg']=data['bwt']*0.0283495

# %%
data
# Out:
#       bwt  gestation  parity  age  height  weight  smoke  altura_madre_cms  \
# 0     120        284       0   27      62     100      0            157.48
# 1     113        282       0   33      64     135      0            162.56
# 2     128        279       0   28      64     115      1            162.56
# 3     108        282       0   23      67     125      1            170.18
# 4     136        286       0   25      62      93      0            157.48
# ...   ...        ...     ...  ...     ...     ...    ...               ...
# 1169  113        275       1   27      60     100      0            152.40
# 1170  128        265       0   24      67     120      0            170.18
# 1171  130        291       0   30      65     150      1            165.10
# 1172  125        281       1   21      65     110      0            165.10
# 1173  117        297       0   38      65     129      0            165.10
#
#       peso_guagua_kg
# 0           3.401940
# 1           3.203493
# ...

# %%
data['altura_madre_cms'].hist(cumulative=True,density=1,bins=100, color='green', label='Prob acum Altura Madre')
#gest = gestacion
gest_1=data[data.parity==1]
gest_2=data[data.parity==0]
plt.xlabel('Altura madre')
plt.ylabel('Prob Acumulada')
plt.legend()
plt.show()

# %%
#gest_1["gestation"].hist(cumulative.True,density=1,bins=100)
#plt.show()

# %%
#gest_2['gestation'].hist(cumulative.True,density=1,bins=100)
#plt.show()

# %%
df = pd.DataFrame([columns=['altura_madre_cms', 'peso_guagua_kg', 'weight'])
                   
data = df.plot.scatter(x='altura_madre_cms',
                      y='peso_guagua_kg',
                      c='weight',
                      colormap='viridis')
# Out:
#   File "<ipython-input-93-311ce1cb9b90>", line 1
#     df = pd.DataFrame([columns=['altura_madre_cms', 'peso_guagua_kg', 'weight'])
#                               ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame([['altura_madre_cms'], ['peso_guagua_kg'], [weight]],
                  columns=['length', 'width', 'species'])
ax1 = df.plot.scatter(x='length',
                      y='width',
                      c='DarkBlue')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-48df36582f5a> in <module>
# ----> 1 df = pd.DataFrame([['altura_madre_cms'], ['peso_guagua_kg'], [weight]],
#       2                   columns=['length', 'width', 'species'])
#       3 ax1 = df.plot.scatter(x='length',
#       4                       y='width',
#       5                       c='DarkBlue')
#
# NameError: name 'weight' is not defined

# %%
ax2 = df.plot.scatter(x='length',
                      y='width',
                      c='species',
                      colormap='viridis')
