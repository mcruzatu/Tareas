# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy
data_1 = pd.read_csv('https://raw.githubusercontent.com/leoferres/gitiele356b/main/data/hdi.csv')
data_2 = pd.read_csv('https://raw.githubusercontent.com/leoferres/gitiele356b/main/data/pobXedadCenso.csv')
data_3= pd.read_csv('https://raw.githubusercontent.com/leoferres/gitiele356b/main/data/pobXedadCenso.csv')

# %%
data_1['Riqueza'] = data_1['HDI']

# %%
data_1
# Out:
#     comuna       LEI        II        EI    idh       HDI   Riqueza
# 0    13101  0.791672  0.873137  0.924099  0.807  0.861222  0.861222
# 1    13102  0.782817  0.800343  0.713499  0.743  0.764616  0.764616
# 2    13103  0.752447  0.750382  0.657961  0.683  0.718874  0.718874
# 3    13104  0.784872  0.760697  0.705426  0.707  0.749584  0.749584
# 4    13105  0.777236  0.780019  0.673876  0.711  0.742015  0.742015
# 5    13106  0.790810  0.784378  0.729145  0.735  0.767604  0.767604
# 6    13107  0.726330  0.775631  0.641707  0.737  0.712375  0.712375
# 7    13108  0.821551  0.751105  0.722493  0.709  0.763935  0.763935
# 8    13109  0.856570  0.835740  0.860235  0.775  0.850780  0.850780
# 9    13110  0.773094  0.824255  0.791155  0.804  0.795888  0.795888
# 10   13111  0.763582  0.751721  0.668837  0.689  0.726793  0.726793
# 11   13112  0.673794  0.758585  0.642574  0.679  0.689951  0.689951
# 12   13113  0.890647  0.948908  0.968223  0.883  0.935337  0.935337
# ...

# %%
data_1['Riqueza'].hist(cumulative=True,density=1,bins=100, color='green', label='Prob acum Riqueza')
# Out:
# <AxesSubplot:>

# %%
data_3
# Out:
#         COMUNA EDAD_0A5 EDAD_6A14 EDAD_15A64 EDAD_65YMAS
# 0         1101        0         0         15           0
# 1         1101        *         *         54          10
# 2         1101        *         0         28           *
# 3         1101        *         7         49           *
# 4         1101        *         *         26           7
# ...        ...      ...       ...        ...         ...
# 180494   15202        *         *          6           4
# 180495   15202        0         0          0           0
# 180496   15202        0         0          0           0
# 180497   15202        *         0          9           *
# 180498   15202        *         0          0           *
#
# [180499 rows x 5 columns]

# %%
data_2
# Out:
#         COMUNA EDAD_0A5 EDAD_6A14 EDAD_15A64 EDAD_65YMAS
# 0         1101        0         0         15           0
# 1         1101        *         *         54          10
# 2         1101        *         0         28           *
# 3         1101        *         7         49           *
# 4         1101        *         *         26           7
# ...        ...      ...       ...        ...         ...
# 180494   15202        *         *          6           4
# 180495   15202        0         0          0           0
# 180496   15202        0         0          0           0
# 180497   15202        *         0          9           *
# 180498   15202        *         0          0           *
#
# [180499 rows x 5 columns]

# %%
#Las personas vacunadas van a tender a ser las de más edad y como la gente de mayor edad tiende a tener mas ingresos, y siendo en este caso la vacunación por grupo etario,
#es claro pensar que se vacunaran antes porque va desde las personas que tienen mayor edad a la de menor edad, entonces no es que tenga que ver que las personas de mayor ingreso
#se vacunen antes, sino que tiene que ver con la edad
